# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error
from sklearn.metrics.pairwise import cosine_similarity
from scipy.stats import pearsonr
import numpy as np
import joblib  # For saving models
from spacy.compat import pickle
# Out:
# /Users/aswathshakthi/PycharmProjects/venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
data_path = "/Users/aswathshakthi/PycharmProjects/MLOps/3.Semantic-Textual-Similarity-NLP/data/clinic_c.csv"
df = pd.read_csv(data_path)
df.head()
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                Sent1  \
# 0                                                                                                                                                                                                                                                                                                                                                       Insulin NPH Human [NOVOLIN N] 100 unit/mL suspension subcutaneous as directed by prescriber.
# 1                                                                                                                                                                                                                                                                                                        Patient arrives ambulatory, Gait steady, History obtained from patient, Patient appears comfortable, Patient cooperative, alert, Skin warm.
# 2                                                                                                                                                                                                                                                                                                                                                  Peripheral IV site, established in the right forearm, using an 18 gauge catheter, in one attempt.
# 3   No: new confusion or inability to stay alert and awake; currently struggling to breathe, even while inactive or resting; currently feeling like you are going to collapse every time you stand (sit); vomit that looks like ground coffee; vomiting blood; uncontrollable or continuous rectal bleeding; black, sticky, tar-like stools; heavy vaginal bleeding or purple or red rash/blotches that stay when pressed by a glass (purpural rash)
# 4                                                                                                                                                                                                                                                                                          Spent 15 minutes with the patient and greater than 50% of this time was spent counseling the patient regarding diagnosis and available treatment options.
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               Sent2  \
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          Insulin NPH Human [NOVOLIN N] 100 unit/mL suspension 63-76 units subcutaneous as directed by prescriber.
# 1                                                                                                                                                                                                                                                                                                                                                                                                          Complex assessment performed, Patient arrives ambulatory, Gait steady, History obtained from patient, Patient appears, anxious, in distress due to pain, Patient cooperative, alert, Oriented to person, place and time.
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           Peripheral IV site, present prior to arrival, established in the right hand, using a 20 gauge catheter.
# 3   No: new confusion or inability to stay alert and awake; any chest pain or discomfort; sudden, CURRENTand excruciating ripping or stabbing pain characteristic of a dissecting aortic aneurysm; newly painful or blue toes on one side; currently struggling to breathe, even while inactive or resting; currently feeling like you are going to collapse every time you stand (sit); vomit that looks like ground coffee; vomiting blood; uncontrollable or continuous rectal bleeding; black, sticky, tar-like stools; heavy vaginal bleeding or purple or red rash/blotches that stay when pressed by a glass (purpural rash)
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    Nurse visit ten minutes, over half of which was spent in counseling and point-of-care testing.
#
#    Score
# 0   3.50
# 1   2.50
# 2   3.45
# 3   4.00
# 4   3.00

# %%
# Split into train/test sets
train_num = int(df.shape[0]*0.9)

train = df[["Sent1","Sent2"]][:train_num]
train_labels = df["Score"][:train_num]

dev= df[["Sent1","Sent2"]][train_num:]
dev_labels = df["Score"][train_num:]

# %%
# Combine Sent1 and Sent2 for unified vectorization
vectorizer = TfidfVectorizer()
vectorizer.fit(train["Sent1"].tolist()+train["Sent2"].tolist())
# Out:
# TfidfVectorizer()

# %%
# Transform train and test sets
train_vecs1 = vectorizer.transform(train.Sent1.tolist())
train_vecs2 = vectorizer.transform(train.Sent2.tolist())

dev_vecs1 = vectorizer.transform(dev.Sent1.tolist())
dev_vecs2 = vectorizer.transform(dev.Sent2.tolist())


# Store feature names for analysis
features = vectorizer.get_feature_names_out()
print(f"TF-IDF Vocabulary Size: {len(features)}")
# Out:
# TF-IDF Vocabulary Size: 2651

# %%
train_features = np.hstack([train_vecs1.toarray(), train_vecs2.toarray()])
test_features = np.hstack([dev_vecs1.toarray(), dev_vecs2.toarray()])


def calculate_cosine_similarity(vecs1, vecs2):
    return np.array([cosine_similarity(vecs1[i], vecs2[i])[0][0] for i in range(vecs1.shape[0])])

train_cosine_sim = calculate_cosine_similarity(train_vecs1, train_vecs2)
dev_cosine_sim = calculate_cosine_similarity(dev_vecs1, dev_vecs2)

# Append cosine similarity as a feature
train_features = np.hstack([train_vecs1.toarray(), train_vecs2.toarray(), train_cosine_sim.reshape(-1, 1)])
dev_features = np.hstack([dev_vecs1.toarray(), dev_vecs2.toarray(), dev_cosine_sim.reshape(-1, 1)])

# %%
import optuna
from sklearn.model_selection import cross_val_score

def objective(trial):
    rf = RandomForestRegressor(
        n_estimators=trial.suggest_int('n_estimators', 100, 1000),
        max_depth=trial.suggest_int('max_depth', 5, 50),
        min_samples_split=trial.suggest_int('min_samples_split', 2, 20),
        min_samples_leaf=trial.suggest_int('min_samples_leaf', 1, 10),
        max_features=trial.suggest_categorical('max_features', ['sqrt', 'log2', None])
    )
    scores = cross_val_score(rf, train_features, train_labels, cv=5, scoring='neg_mean_squared_error')
    return -scores.mean()

study = optuna.create_study(direction='minimize',study_name="Similarity", storage="sqlite:///db.sqlite3")
study.optimize(objective, n_trials=50,n_jobs=-1)

print("Best Parameters:", study.best_params)
best_model = RandomForestRegressor(**study.best_params)

best_model.fit(train_features, train_labels)


# Save the trained models for later inference
joblib.dump(best_model, '/Users/aswathshakthi/PycharmProjects/MLOps/3.Semantic-Textual-Similarity-NLP/models/tfidf_rf_model.pkl')


print("Models saved successfully!")
# Out:
# [I 2024-12-19 14:55:07,369] A new study created in RDB with name: Similarity
# [I 2024-12-19 14:55:13,041] Trial 2 finished with value: 1.2921191504365437 and parameters: {'n_estimators': 149, 'max_depth': 10, 'min_samples_split': 11, 'min_samples_leaf': 3, 'max_features': 'log2'}. Best is trial 2 with value: 1.2921191504365437.
# [I 2024-12-19 14:55:17,540] Trial 7 finished with value: 1.1653630957541776 and parameters: {'n_estimators': 232, 'max_depth': 49, 'min_samples_split': 8, 'min_samples_leaf': 2, 'max_features': 'log2'}. Best is trial 7 with value: 1.1653630957541776.
# [I 2024-12-19 14:55:17,974] Trial 3 finished with value: 1.316150045485443 and parameters: {'n_estimators': 305, 'max_depth': 31, 'min_samples_split': 19, 'min_samples_leaf': 5, 'max_features': 'log2'}. Best is trial 7 with value: 1.1653630957541776.
# [I 2024-12-19 14:55:18,890] Trial 0 finished with value: 0.9892361795474635 and parameters: {'n_estimators': 217, 'max_depth': 15, 'min_samples_split': 7, 'min_samples_leaf': 1, 'max_features': 'sqrt'}. Best is trial 0 with value: 0.9892361795474635.
# [I 2024-12-19 14:55:20,702] Trial 4 finished with value: 1.3013780233815195 and parameters: {'n_estimators': 383, 'max_depth': 26, 'min_samples_split': 7, 'min_samples_leaf': 4, 'max_features': 'log2'}. Best is trial 0 with value: 0.9892361795474635.
# [I 2024-12-19 14:55:24,635] Trial 13 finished with value: 1.3215454572089278 and parameters: {'n_estimators': 170, 'max_depth': 26, 'min_samples_split': 2, 'min_samples_leaf': 5, 'max_features': 'log2'}. Best is trial 0 with value: 0.9892361795474635.
# [I 2024-12-19 14:55:30,066] Trial 1 finished with value: 1.3346284103609516 and parameters: {'n_estimators': 767, 'max_depth': 9, 'min_samples_split': 14, 'min_samples_leaf': 7, 'max_features': 'log2'}. Best is trial 0 with value: 0.9892361795474635.
# [I 2024-12-19 14:55:30,486] Trial 11 finished with value: 1.1051385473436728 and parameters: {'n_estimators': 319, 'max_depth': 9, 'min_samples_split': 4, 'min_samples_leaf': 4, 'max_features': 'sqrt'}. Best is trial 0 with value: 0.9892361795474635.
# [I 2024-12-19 14:55:31,290] Trial 12 finished with value: 1.2930238097163835 and parameters: {'n_estimators': 410, 'max_depth': 41, 'min_samples_split': 6, 'min_samples_leaf': 4, 'max_features': 'log2'}. Best is trial 0 with value: 0.9892361795474635.
# [I 2024-12-19 14:55:32,739] Trial 8 finished with value: 0.9617032313642598 and parameters: {'n_estimators': 501, 'max_depth': 47, 'min_samples_split': 16, 'min_samples_leaf': 5, 'max_features': 'sqrt'}. Best is trial 8 with value: 0.9617032313642598.
# [I 2024-12-19 14:55:55,792] Trial 10 finished with value: 0.9778454863836054 and parameters: {'n_estimators': 994, 'max_depth': 18, 'min_samples_split': 4, 'min_samples_leaf': 3, 'max_features': 'sqrt'}. Best is trial 8 with value: 0.9617032313642598.
# [I 2024-12-19 14:56:01,399] Trial 18 finished with value: 0.8716389684473604 and parameters: {'n_estimators': 599, 'max_depth': 32, 'min_samples_split': 6, 'min_samples_leaf': 2, 'max_features': 'sqrt'}. Best is trial 18 with value: 0.8716389684473604.
# [I 2024-12-19 14:56:10,719] Trial 15 finished with value: 0.5027519877200446 and parameters: {'n_estimators': 174, 'max_depth': 40, 'min_samples_split': 6, 'min_samples_leaf': 10, 'max_features': None}. Best is trial 15 with value: 0.5027519877200446.
# [I 2024-12-19 14:56:21,331] Trial 17 finished with value: 0.8311927453137621 and parameters: {'n_estimators': 921, 'max_depth': 46, 'min_samples_split': 4, 'min_samples_leaf': 2, 'max_features': 'sqrt'}. Best is trial 15 with value: 0.5027519877200446.
# [I 2024-12-19 14:56:24,467] Trial 20 finished with value: 1.0665752497132086 and parameters: {'n_estimators': 888, 'max_depth': 18, 'min_samples_split': 17, 'min_samples_leaf': 9, 'max_features': 'sqrt'}. Best is trial 15 with value: 0.5027519877200446.
# [I 2024-12-19 14:57:05,569] Trial 14 finished with value: 0.4961706270729268 and parameters: {'n_estimators': 370, 'max_depth': 14, 'min_samples_split': 11, 'min_samples_leaf': 7, 'max_features': None}. Best is trial 14 with value: 0.4961706270729268.
# [I 2024-12-19 14:57:31,552] Trial 25 finished with value: 0.5003573893451195 and parameters: {'n_estimators': 100, 'max_depth': 38, 'min_samples_split': 11, 'min_samples_leaf': 10, 'max_features': None}. Best is trial 14 with value: 0.4961706270729268.
# [I 2024-12-19 14:58:19,756] Trial 6 finished with value: 0.5024842870657965 and parameters: {'n_estimators': 744, 'max_depth': 45, 'min_samples_split': 6, 'min_samples_leaf': 10, 'max_features': None}. Best is trial 14 with value: 0.4961706270729268.
# [I 2024-12-19 14:58:27,985] Trial 19 finished with value: 0.50283626443717 and parameters: {'n_estimators': 665, 'max_depth': 50, 'min_samples_split': 20, 'min_samples_leaf': 10, 'max_features': None}. Best is trial 14 with value: 0.4961706270729268.
# [I 2024-12-19 14:58:34,840] Trial 21 finished with value: 0.5041081856003631 and parameters: {'n_estimators': 583, 'max_depth': 39, 'min_samples_split': 17, 'min_samples_leaf': 10, 'max_features': None}. Best is trial 14 with value: 0.4961706270729268.
# [I 2024-12-19 14:58:47,494] Trial 5 finished with value: 0.49642649520380944 and parameters: {'n_estimators': 811, 'max_depth': 46, 'min_samples_split': 20, 'min_samples_leaf': 7, 'max_features': None}. Best is trial 14 with value: 0.4961706270729268.
# [I 2024-12-19 14:59:04,025] Trial 29 finished with value: 0.5000115884982566 and parameters: {'n_estimators': 106, 'max_depth': 22, 'min_samples_split': 11, 'min_samples_leaf': 7, 'max_features': None}. Best is trial 14 with value: 0.4961706270729268.
# [I 2024-12-19 14:59:08,649] Trial 22 finished with value: 0.5042758051619922 and parameters: {'n_estimators': 680, 'max_depth': 36, 'min_samples_split': 10, 'min_samples_leaf': 10, 'max_features': None}. Best is trial 14 with value: 0.4961706270729268.
# [I 2024-12-19 14:59:14,492] Trial 24 finished with value: 0.5026595019742889 and parameters: {'n_estimators': 654, 'max_depth': 40, 'min_samples_split': 11, 'min_samples_leaf': 10, 'max_features': None}. Best is trial 14 with value: 0.4961706270729268.
# [I 2024-12-19 14:59:15,567] Trial 9 finished with value: 0.4902557498195234 and parameters: {'n_estimators': 863, 'max_depth': 48, 'min_samples_split': 6, 'min_samples_leaf': 6, 'max_features': None}. Best is trial 9 with value: 0.4902557498195234.
# [I 2024-12-19 14:59:44,751] Trial 16 finished with value: 0.5033233857644355 and parameters: {'n_estimators': 980, 'max_depth': 16, 'min_samples_split': 9, 'min_samples_leaf': 10, 'max_features': None}. Best is trial 9 with value: 0.4902557498195234.
# [I 2024-12-19 14:59:55,628] Trial 23 finished with value: 0.5015138446717707 and parameters: {'n_estimators': 824, 'max_depth': 39, 'min_samples_split': 10, 'min_samples_leaf': 10, 'max_features': None}. Best is trial 9 with value: 0.4902557498195234.
# [I 2024-12-19 15:00:19,863] Trial 26 finished with value: 0.499402377994386 and parameters: {'n_estimators': 626, 'max_depth': 37, 'min_samples_split': 11, 'min_samples_leaf': 8, 'max_features': None}. Best is trial 9 with value: 0.4902557498195234.
# [I 2024-12-19 15:00:44,963] Trial 28 finished with value: 0.49672864426345437 and parameters: {'n_estimators': 494, 'max_depth': 37, 'min_samples_split': 11, 'min_samples_leaf': 7, 'max_features': None}. Best is trial 9 with value: 0.4902557498195234.
# [I 2024-12-19 15:00:59,653] Trial 27 finished with value: 0.4946737208719899 and parameters: {'n_estimators': 577, 'max_depth': 35, 'min_samples_split': 11, 'min_samples_leaf': 7, 'max_features': None}. Best is trial 9 with value: 0.4902557498195234.
# [I 2024-12-19 15:01:08,057] Trial 30 finished with value: 0.4912219477754701 and parameters: {'n_estimators': 506, 'max_depth': 35, 'min_samples_split': 12, 'min_samples_leaf': 7, 'max_features': None}. Best is trial 9 with value: 0.4902557498195234.
# [I 2024-12-19 15:01:18,265] Trial 31 finished with value: 0.4911027261351958 and parameters: {'n_estimators': 477, 'max_depth': 22, 'min_samples_split': 13, 'min_samples_leaf': 7, 'max_features': None}. Best is trial 9 with value: 0.4902557498195234.
# [I 2024-12-19 15:01:19,764] Trial 33 finished with value: 0.49556429144230874 and parameters: {'n_estimators': 448, 'max_depth': 21, 'min_samples_split': 15, 'min_samples_leaf': 7, 'max_features': None}. Best is trial 9 with value: 0.4902557498195234.
# [I 2024-12-19 15:01:21,960] Trial 32 finished with value: 0.4921690172098506 and parameters: {'n_estimators': 479, 'max_depth': 20, 'min_samples_split': 13, 'min_samples_leaf': 7, 'max_features': None}. Best is trial 9 with value: 0.4902557498195234.
# [I 2024-12-19 15:02:19,474] Trial 34 finished with value: 0.5074533747148275 and parameters: {'n_estimators': 812, 'max_depth': 5, 'min_samples_split': 14, 'min_samples_leaf': 7, 'max_features': None}. Best is trial 9 with value: 0.4902557498195234.
# [I 2024-12-19 15:02:25,117] Trial 37 finished with value: 0.49386576961427514 and parameters: {'n_estimators': 458, 'max_depth': 43, 'min_samples_split': 13, 'min_samples_leaf': 7, 'max_features': None}. Best is trial 9 with value: 0.4902557498195234.
# [I 2024-12-19 15:03:10,744] Trial 39 finished with value: 0.490275887864761 and parameters: {'n_estimators': 473, 'max_depth': 33, 'min_samples_split': 15, 'min_samples_leaf': 6, 'max_features': None}. Best is trial 9 with value: 0.4902557498195234.
# [I 2024-12-19 15:03:25,268] Trial 40 finished with value: 0.49062603121552184 and parameters: {'n_estimators': 498, 'max_depth': 30, 'min_samples_split': 13, 'min_samples_leaf': 6, 'max_features': None}. Best is trial 9 with value: 0.4902557498195234.
# [I 2024-12-19 15:03:32,445] Trial 35 finished with value: 0.4948710210169288 and parameters: {'n_estimators': 836, 'max_depth': 44, 'min_samples_split': 13, 'min_samples_leaf': 7, 'max_features': None}. Best is trial 9 with value: 0.4902557498195234.
# [I 2024-12-19 15:03:36,549] Trial 41 finished with value: 0.48945829063506235 and parameters: {'n_estimators': 502, 'max_depth': 32, 'min_samples_split': 13, 'min_samples_leaf': 6, 'max_features': None}. Best is trial 41 with value: 0.48945829063506235.
# [I 2024-12-19 15:03:43,532] Trial 48 finished with value: 1.32949500173444 and parameters: {'n_estimators': 723, 'max_depth': 31, 'min_samples_split': 15, 'min_samples_leaf': 6, 'max_features': 'log2'}. Best is trial 41 with value: 0.48945829063506235.
# [I 2024-12-19 15:03:43,765] Trial 43 finished with value: 0.48846559802842615 and parameters: {'n_estimators': 517, 'max_depth': 29, 'min_samples_split': 13, 'min_samples_leaf': 6, 'max_features': None}. Best is trial 43 with value: 0.48846559802842615.
# [I 2024-12-19 15:03:44,201] Trial 42 finished with value: 0.48764164402374305 and parameters: {'n_estimators': 533, 'max_depth': 43, 'min_samples_split': 14, 'min_samples_leaf': 6, 'max_features': None}. Best is trial 42 with value: 0.48764164402374305.
# [I 2024-12-19 15:03:44,541] Trial 49 finished with value: 1.3255827732608385 and parameters: {'n_estimators': 542, 'max_depth': 30, 'min_samples_split': 15, 'min_samples_leaf': 6, 'max_features': 'log2'}. Best is trial 42 with value: 0.48764164402374305.
# [I 2024-12-19 15:03:46,596] Trial 36 finished with value: 0.4938303139606036 and parameters: {'n_estimators': 856, 'max_depth': 33, 'min_samples_split': 13, 'min_samples_leaf': 7, 'max_features': None}. Best is trial 42 with value: 0.48764164402374305.
# [I 2024-12-19 15:03:52,111] Trial 45 finished with value: 0.4879367049830606 and parameters: {'n_estimators': 330, 'max_depth': 30, 'min_samples_split': 13, 'min_samples_leaf': 6, 'max_features': None}. Best is trial 42 with value: 0.48764164402374305.
# [I 2024-12-19 15:04:17,237] Trial 38 finished with value: 0.4905358468915616 and parameters: {'n_estimators': 827, 'max_depth': 32, 'min_samples_split': 13, 'min_samples_leaf': 6, 'max_features': None}. Best is trial 42 with value: 0.48764164402374305.
# [I 2024-12-19 15:04:18,402] Trial 44 finished with value: 0.48903937624348925 and parameters: {'n_estimators': 498, 'max_depth': 29, 'min_samples_split': 13, 'min_samples_leaf': 6, 'max_features': None}. Best is trial 42 with value: 0.48764164402374305.
# [I 2024-12-19 15:04:57,723] Trial 46 finished with value: 0.49113347251376716 and parameters: {'n_estimators': 549, 'max_depth': 29, 'min_samples_split': 13, 'min_samples_leaf': 6, 'max_features': None}. Best is trial 42 with value: 0.48764164402374305.
# [I 2024-12-19 15:05:04,697] Trial 47 finished with value: 0.4892252731210057 and parameters: {'n_estimators': 549, 'max_depth': 29, 'min_samples_split': 15, 'min_samples_leaf': 6, 'max_features': None}. Best is trial 42 with value: 0.48764164402374305.
# Best Parameters: {'n_estimators': 533, 'max_depth': 43, 'min_samples_split': 14, 'min_samples_leaf': 6, 'max_features': None}
# Models saved successfully!

# %%
# Predict using Random Forest models
model = joblib.load("/Users/aswathshakthi/PycharmProjects/MLOps/3.Semantic-Textual-Similarity-NLP/models/tfidf_rf_model.pkl")
dev_pred = model.predict(dev_features)

# Calculate Mean Squared Error (MSE)
mse = mean_squared_error(dev_labels, dev_pred)

mse
# Out:
# 0.4330451743295736

# %%
# Correlation for Train Data
train_corr, _ = pearsonr(train_cosine_sim, train_labels)
print(f"Pearson Correlation for Train: {train_corr:.5f}")

# Correlation for Test Data
test_corr, _ = pearsonr(dev_cosine_sim, dev_labels)
print(f"Pearson Correlation for Test: {test_corr:.5f}")
# Out:
# Pearson Correlation for Train: 0.69718
# Pearson Correlation for Test: 0.72148

# %%
results = {
    "mse1": mse1,

    "train_corr": train_corr,
    "test_corr": test_corr,
}
print("Results:", results)
# Out:
# Results: {'mse1': 0.4340256695387805, 'train_corr': 0.6971838627918355, 'test_corr': 0.72147900961106}

# %%
print(vectorizer.vocabulary_)
# Out:
# {'insulin': 1251, 'nph': 1586, 'human': 1147, 'novolin': 1584, '100': 8, 'unit': 2484, 'ml': 1484, 'suspension': 2290, 'subcutaneous': 2260, 'as': 222, 'directed': 711, 'by': 376, 'prescriber': 1806, 'patient': 1712, 'arrives': 216, 'ambulatory': 152, 'gait': 1019, 'steady': 2220, 'history': 1127, 'obtained': 1605, 'from': 1006, 'appears': 194, 'comfortable': 488, 'cooperative': 575, 'alert': 133, 'skin': 2135, 'warm': 2572, 'peripheral': 1732, 'iv': 1299, 'site': 2127, 'established': 850, 'in': 1187, 'the': 2353, 'right': 2019, 'forearm': 988, 'using': 2515, 'an': 157, '18': 27, 'gauge': 1022, 'catheter': 414, 'one': 1626, 'attempt': 245, 'no': 1564, 'new': 1558, 'confusion': 532, 'or': 1643, 'inability': 1188, 'to': 2392, 'stay': 2219, 'and': 160, 'awake': 263, 'currently': 617, 'struggling': 2254, 'breathe': 355, 'even': 853, 'while': 2601, 'inactive': 1190, 'resting': 2000, 'feeling': 929, 'like': 1362, 'you': 2645, 'are': 207, 'going': 1054, 'collapse': 479, 'every': 857, 'time': 2384, 'stand': 2206, 'sit': 2126, 'vomit': 2565, 'that': 2352, 'looks': 1391, 'ground': 1068, 'coffee': 476, 'vomiting': 2566, 'blood': 332, 'uncontrollable': 2469, 'continuous': 564, 'rectal': 1927, 'bleeding': 326, 'black': 323, 'sticky': 2226, 'tar': 2320, 'stools': 2232, 'heavy': 1106, 'vaginal': 2524, 'purple': 1872, 'red': 1932, 'rash': 1889, 'blotches': 334, 'when': 2598, 'pressed': 1813, 'glass': 1044, 'purpural': 1874, 'spent': 2181, '15': 22, 'minutes': 1477, 'with': 2617, 'greater': 1062, 'than': 2351, '50': 46, 'of': 1616, 'this': 2370, 'was': 2575, 'counseling': 590, 'regarding': 1944, 'diagnosis': 692, 'available': 259, 'treatment': 2438, 'options': 1641, 'newly': 1560, 'painful': 1679, 'neck': 1544, 'difficulty': 702, 'bending': 308, 'paralyzed': 1689, 'face': 909, 'muscles': 1525, 'severe': 2091, 'dizziness': 740, 'up': 2495, 'purpuric': 1875, 'cardiovascular': 397, 'assessment': 235, 'findings': 950, 'include': 1194, 'heart': 1101, 'rate': 1891, 'normal': 1571, 'rhythm': 2016, 'atrial': 244, 'fibrillation': 939, 'controlled': 568, 'ventricular': 2534, 'response': 1997, 'discussed': 721, 'necessity': 1543, 'other': 1653, 'members': 1453, 'healthcare': 1098, 'team': 2326, 'both': 343, 'male': 1414, 'female': 933, 'participating': 1697, 'procedure': 1830, 'negative': 1549, 'gastrointestinal': 1021, 'review': 2011, 'systems': 2307, 'historian': 1126, 'denies': 658, 'abdominal': 61, 'pain': 1678, 'nausea': 1536, 'given': 1040, 'current': 615, 'medication': 1442, 'regimen': 1946, 'following': 981, 'parameters': 1690, 'should': 2105, 'be': 289, 'monitored': 1496, 'outpatient': 1662, 'providers': 1858, 'none': 1568, 'risks': 2024, 'benefits': 310, 'were': 2591, 'consented': 538, 'complete': 506, 'swallow': 2293, 'pressure': 1814, 'tightness': 2383, 'chest': 440, 'jaw': 1301, 'arm': 211, 'goals': 1052, 'alternatives': 147, 'advanced': 110, 'directives': 714, 'surgical': 2288, 'explained': 886, 'plan': 1758, 'expressed': 891, 'understanding': 2475, 'content': 559, 'copy': 581, 'note': 1576, 'via': 2546, 'stretcher': 2247, 'emergency': 817, 'medical': 1441, 'services': 2083, 'unsteady': 2493, 'lift': 1356, 'cart': 409, 'oriented': 1649, 'person': 1738, 'place': 1755, 'dimension': 709, 'emotional': 819, 'behavioral': 302, 'cognitive': 477, 'conditions': 526, 'complications': 513, 'received': 1909, 'risk': 2023, 'score': 2053, 'interference': 1264, 'addiction': 93, 'recovery': 1926, 'concerns': 522, 'related': 1954, 'consequences': 540, 'effects': 801, 'is': 1289, 'able': 64, 'view': 2549, 'these': 2364, 'part': 1693, 'identified': 1158, 'illness': 1165, 'learning': 1336, 'need': 1545, 'patients': 1713, 'primary': 1821, 'language': 1321, 'english': 830, 'barriers': 282, 'interventions': 1272, 'used': 2512, 'address': 97, 'teaching': 2325, 'methods': 1463, 'included': 1195, 'printed': 1823, 'instructions': 1249, 'verbal': 2535, 'demonstrated': 654, 'verbalized': 2538, 'discharge': 716, 'they': 2365, 'do': 742, 'not': 1575, 'have': 1088, 'dates ...
